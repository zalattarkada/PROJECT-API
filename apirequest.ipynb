# %%
import requests
import json
import pandas as pd

# %%
# establecemos la url y la key
key = '13dc080d47f14e8a9a759ac836d36aaf'
url = f'https://api.spoonacular.com/recipes/complexSearch?apiKey={key}&number=100&addRecipeInformation=true'

# hacemos la request
res = requests.get(url)

# convertimos a jason
recipes = res.json()['results']

# convertimos a df
df = pd.DataFrame(recipes)

# %%
df
# Out:
#     vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0         True   True        True       True         True  False        False
# 1         True   True        True       True         True  False         True
# 2         True  False       False      False         True  False         True
# 3        False  False        True       True         True  False         True
# 4         True   True        True       True         True  False        False
# ..         ...    ...         ...        ...          ...    ...          ...
# 95       False  False        True       True         True  False        False
# 96        True   True        True       True         True  False        False
# 97       False  False        True       True         True  False        False
# 98        True  False        True       True        False  False        False
# 99        True  False        True      False         True  False        False
#
# ...

# %%
# casteamos las columnas para ver con que trabajamos
df.to_csv('data/recipes.csv', index=False)
